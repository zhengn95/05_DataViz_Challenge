# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
# This analysis uses complete data from Pymaceuticals's most recent animal study. The purpose of this study was to compare the performance of Pymaceuticals’ drug of interest, Capomulin, against the other treatment regimens.
#
# In this analysis, I was tasked with generating all of the tables and figures needed for the technical report of the clinical study and a summary of the study results (see README.md file).

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
merged_df = pd.merge(mouse_metadata, study_results, how = 'right', on = ['Mouse ID', 'Mouse ID'])
reordered_df = ['Mouse ID', 'Timepoint', 'Tumor Volume (mm3)', 'Metastatic Sites', 'Drug Regimen', 
    'Sex', 'Age_months', 'Weight (g)']
reordered_merged_df = merged_df[reordered_df]

# Display the data table for preview
reordered_merged_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice.
len(reordered_merged_df['Mouse ID'].unique())
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicated_df = reordered_merged_df[reordered_merged_df.duplicated(subset=['Mouse ID', 'Timepoint'], keep=False)]
duplicated_df['Mouse ID'].unique()
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID.
duplicated_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 107      g989          0           45.000000                 0     Propriva
# 137      g989          0           45.000000                 0     Propriva
# 329      g989          5           48.786801                 0     Propriva
# 360      g989          5           47.570392                 0     Propriva
# 620      g989         10           51.745156                 0     Propriva
# 681      g989         10           49.880528                 0     Propriva
# 815      g989         15           51.325852                 1     Propriva
# 869      g989         15           53.442020                 0     Propriva
# 950      g989         20           55.326122                 1     Propriva
# 1111     g989         20           54.657650                 1     Propriva
#
#          Sex  Age_months  Weight (g)
# 107   Female          21          26
# 137   Female          21          26
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
cleaned_df = reordered_merged_df[reordered_merged_df['Mouse ID'] != 'g989']
cleaned_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0                45.0                 0    Capomulin
# 1     f932          0                45.0                 0     Ketapril
# 2     g107          0                45.0                 0     Ketapril
# 3     a457          0                45.0                 0     Ketapril
# 4     c819          0                45.0                 0     Ketapril
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male          15          29
# 2  Female           2          29
# 3  Female          11          30
# 4    Male          21          25

# %%
# Checking the number of mice in the clean DataFrame.
len(cleaned_df['Mouse ID'].unique())
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen:
groupby_drug = cleaned_df.groupby('Drug Regimen')

# mean, median, variance, standard deviation, and SEM of the tumor volume. 
mean_df = groupby_drug['Tumor Volume (mm3)'].mean()
median_df = groupby_drug['Tumor Volume (mm3)'].median()
variance_df = groupby_drug['Tumor Volume (mm3)'].var()
std_df = groupby_drug['Tumor Volume (mm3)'].std()
sem_df = groupby_drug['Tumor Volume (mm3)'].sem()

# Assemble the resulting series into a single summary DataFrame.
SummaryStats_df = pd.DataFrame({'Mean Tumor Volume': mean_df, 'Median Tumor Volume': median_df, 
                               'Tumor Volume Variance': variance_df, 'Tumor Volume Std. Dev.': std_df,
                               'Tumor Volume Std. Err.': sem_df})
SummaryStats_df.sort_values('Drug Regimen')
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# ...

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
SummaryStats_agg = groupby_drug.agg({'Tumor Volume (mm3)' : ['mean', 'median', 'var', 'std', 'sem']})
SummaryStats_agg
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
Drug_vs_Timepoint = groupby_drug.size().reset_index(name = 'Timepoint')
Drug_vs_Timepoint_sorted = Drug_vs_Timepoint.sort_values('Timepoint', ascending = False)
Drug_vs_Timepoint_sorted.plot(x = 'Drug Regimen', y = 'Timepoint', kind= 'bar', legend = False,
                                   title= 'Drug Regimen vs Timepoint',
                                   xlabel= 'Drug Regimen',
                                   ylabel= '# of Observed Mouse Timepoints')
plt.show()

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
xDrug_Regimen = Drug_vs_Timepoint_sorted['Drug Regimen']
yTimepoint = Drug_vs_Timepoint_sorted['Timepoint']
plt.bar(xDrug_Regimen, yTimepoint)
plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')
plt.xticks(rotation = 90)
plt.show()

# %%
groupby_sex = cleaned_df.groupby('Sex').size()
groupby_sex = groupby_sex.sort_values(ascending=False)
groupby_sex.head()
# Out:
# Sex
# Male      958
# Female    922
# dtype: int64

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
groupby_sex.plot(kind='pie', y='Sex', autopct="%1.1f%%")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
labels = ['Male', 'Female']
plt.pie(groupby_sex, labels=labels,
        autopct="%1.1f%%")
plt.ylabel('Sex')
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

# Start by getting the last (greatest) timepoint for each mouse
grouped_mouse = cleaned_df.groupby(['Mouse ID'])['Timepoint'].max()

# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
grouped_merged = pd.merge(cleaned_df, grouped_mouse, on = ['Mouse ID', 'Timepoint'], how = 'right')
grouped_merged
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0       a203         45           67.973419                 2    Infubinol
# 1       a251         45           65.525743                 1    Infubinol
# 2       a262         45           70.717621                 4      Placebo
# 3       a275         45           62.999356                 3     Ceftamin
# 4       a366         30           63.440686                 1     Stelasyn
# ..       ...        ...                 ...               ...          ...
# 243     z435         10           48.710661                 0     Propriva
# 244     z578         45           30.638696                 0     Ramicane
# 245     z581         45           62.754451                 3    Infubinol
# 246     z795         45           65.741070                 3     Naftisol
# 247     z969         45           73.867845                 4     Naftisol
#
#         Sex  Age_months  Weight (g)
# ...

# %%
# Put treatments into a list for for loop (and later for plot labels)
regimens = ['Capomulin', 'Ramicane', 'Infubinol', 'Ceftamin']
        
# Create empty list to fill with tumor vol data (for plotting)
tumor_volumes = {}

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
for regimen in regimens:
    # Locate the rows which contain mice on each drug and get the tumor volumes
    subset = grouped_merged.loc[grouped_merged['Drug Regimen'] == regimen, 'Tumor Volume (mm3)']
    
    # add subset 
    tumor_volumes[regimen] = subset.tolist()
    
    # Determine outliers using upper and lower bounds
    Q1 = subset.quantile(0.25)
    Q3 = subset.quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - (1.5 * IQR)
    upper_bound  = Q3 + (1.5 * IQR)
    outliers = subset.loc[(subset < lower_bound) | (subset > upper_bound)]

final_tumor_volume = [tumor_volumes[regimen] for regimen in regimens]

# %%
# Generate a box plot that shows the distribution of the tumor volume for each treatment group.
plt.boxplot(final_tumor_volume, labels=regimens,flierprops=dict(markerfacecolor='red', marker='o', markersize=12))
plt.title('Tumor Volume Distribution by Treatment Group')
plt.xlabel('Drug Regimen')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin
condition = (cleaned_df['Mouse ID'] == 'l509') & (cleaned_df['Drug Regimen'] == 'Capomulin')
new_cleaned_df = cleaned_df.loc[condition, :]

xTimepoint = new_cleaned_df['Timepoint']
yTumor_volume = new_cleaned_df['Tumor Volume (mm3)']

plt.plot(xTimepoint, yTumor_volume)
plt.title('Capomulin treatment of mouse l509')
plt.xlabel('Timepoints (days)')
plt.ylabel('Tumor Volume (mm3)')
plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen
capomulin_data = cleaned_df.loc[(cleaned_df['Drug Regimen'] == 'Capomulin'), :]

xWeight = capomulin_data.groupby('Mouse ID')['Weight (g)'].mean()
yAvg_tumor_volume = capomulin_data.groupby('Mouse ID')['Tumor Volume (mm3)'].mean()

plt.scatter(xWeight, yAvg_tumor_volume, marker='o', facecolors='purple', edgecolors='purple', s=weight*2, alpha=0.75)
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)')
plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen

# Import additional dependencies
from scipy.stats import linregress

correlation = st.pearsonr(xWeight, yAvg_tumor_volume)
(slope, intercept, rvalue, pvalue, stderr) = linregress(xWeight, yAvg_tumor_volume)
regress_values = xWeight * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(xWeight, yAvg_tumor_volume, marker='o', facecolors='purple', edgecolors='purple', s=weight*2, alpha=0.75)
plt.plot(xWeight,regress_values,"r-")
plt.annotate(line_eq,(20,38),fontsize=12,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume (Capomulin Regimen)')

print(f"The correlation between mouse weight and the average tumor volume is {round(correlation[0],2)}")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84
# The r-squared is: 0.7088568047708723
